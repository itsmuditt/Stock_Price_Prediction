# %% [markdown]
# <a href="https://colab.research.google.com/github/itsmuditt/Stock_Price_Prediction/blob/main/DL_Stock_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##*`Imports and Data Call through 'yfinance' API`*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pip
import time
import datetime

# %%
company = input("Enter the name of company you want Prediction of: ")

# %%
# These dates are not accurate
end_date = datetime.datetime(2023, 10, 21)
start_date = datetime.datetime(2010, 1, 1)

# %%
import yfinance as yf
data = yf.download(f'{company}', start_date, end_date)

# %%
data.to_csv(f'{company}.csv')

# %% [markdown]
# ---

# %% [markdown]
# ##*`Data Preprocessing`*

# %%
prices_df = pd.read_csv(f'{company}.csv', parse_dates=True)

# %%
close_df = prices_df[['Date', 'Adj Close', 'Volume']]
close_df['Next Day'] = close_df['Adj Close'].shift(-1)
close_df.drop(len(close_df)-1, inplace=True)

# %%
close_df['Price_Diff'] = close_df['Next Day']-close_df['Adj Close']
close_df.to_csv('prices_infosys_v2.csv')

# %% [markdown]
# ```
# Dataset for prices has been created and saved.
# ```
#
# ##Computing News Sentiment scores according to Stock Market Dates

# %%
import pandas as pd
import numpy as np

# %%
financial_df = pd.read_csv('financial_scores.csv', index_col=False)
prices_df = pd.read_csv('prices_infosys_v2.csv', index_col=False)

# %%
financial_df.columns

# %%
financial_df = financial_df.drop('Unnamed: 0', axis=1)

# %%
# Reformatting the date in dataset1
financial_df['Date'] = pd.to_datetime(financial_df['Date'], format='%d-%m-%Y').dt.strftime('%d-%m-%Y')

# Reformatting the date in dataset2
prices_df['Date'] = pd.to_datetime(prices_df['Date']).dt.strftime('%d-%m-%Y')

# %%
def rearrange_dates(df_a, df_b):

    # df_a = sentiment_df and df_b = prices_df
    iter_a = df_a.iterrows()
    iter_b = df_b.iterrows()

    scores = []
    dates = []

    row_a = next(iter_a, None)
    row_b = next(iter_b, None)
    flag = False
    # Iterate over the rows of df_a and df_b separately
    for i in range(len(df_a)):
        if flag:
            row_a = next_a
            row_b = next_b

        next_a = next(iter_a, None)
        next_b = next(iter_b, None)

        if (next_a == None) or (next_b == None):
            break
        if next_a[1]['Date'] == next_b[1]['Date']:
            scores.append(row_a[1]['sentiment_score'])
            dates.append(row_a[1]['Date'])
        else:
            date = row_a[1]['Date']
            sum = (row_a[1]['sentiment_score'] * row_a[1]['count'])
            cnt = row_a[1]['count']
            while (next_a != None) and (next_a[1]['Date'] != next_b[1]['Date']):
                sum = sum + (next_a[1]['sentiment_score'] * next_a[1]['count'])
                cnt = cnt + next_a[1]['count']
                next_a = next(iter_a, None)
            scores.append(sum/cnt)
            dates.append(date)
        flag = True


    rearranged_sentiment_df = pd.DataFrame({'sentiment_score': scores, 'Date': dates})
    return rearranged_sentiment_df

# %%
rearranged_df = rearrange_dates(financial_df, prices_df)
rearranged_df.to_csv('rearranged.csv')

# %% [markdown]
# ---
# ###Normalize sentiment scores and Adj Close to compute Impact
# ---

# %%
import pandas as pd

# %%
prices_df = pd.read_csv('prices_infosys_v2.csv', index_col=False)
financial_df = pd.read_csv('rearranged.csv', index_col=False)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler_fin = MinMaxScaler(feature_range=(-1, 1))

# %%
financial_df['scaled_financial_scores'] = scaler_fin.fit_transform(financial_df[['financial_score']])

# %%
prices_df['scaled_diff'] = prices_df['Price_Diff']/prices_df['Price_Diff'].abs().max()

# %%
prices_df['Impact'] = prices_df['scaled_diff'] * financial_df['scaled_financial_scores']
prices_df['Impact'] = prices_df['Impact'].abs()
prices_df.loc[prices_df['scaled_diff'] < 0, 'Impact'] *= -1

# %%
prices_df = prices_df.assign(financial_scores = financial_df['sentiment_score'])

# %%
prices_df = prices_df.assign(scaled_financial_scores = financial_df['scaled_financial_scores'])

# %%
prices_df.to_csv('final_v2.csv')

# %% [markdown]
# ---

# %% [markdown]
# ## LSTM Model

# %%
# !pip install tensorflow --quiet

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras import regularizers
from tensorflow.keras.layers import LeakyReLU
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('final_v2.csv')
df.drop('Unnamed: 0.1', axis = 1, inplace=True)
df.drop('Unnamed: 0', axis = 1, inplace=True)

# %%
df.head(5)
# Out:
#          Date   Adj Close    Volume    Next Day  Price_Diff  scaled_diff  \
# 0  2010-01-04  239.741455   4069264  240.544266    0.802811     0.006381
# 1  2010-01-05  240.544266   6895528  237.034332   -3.509933    -0.027896
# 2  2010-01-06  237.034332   6817288  231.707504   -5.326828    -0.042337
# 3  2010-01-07  231.707504  10892600  226.123688   -5.583817    -0.044379
# 4  2010-01-08  226.123688  12649312  228.459061    2.335373     0.018561
#
#      Impact  financial_scores  scaled_financial_scores
# 0  0.000729          0.138043                 0.114222
# 1 -0.013630          0.207873                 0.488592
# 2 -0.015643          0.185656                 0.369487
# 3 -0.005670          0.092908                -0.127754
# 4  0.000367          0.120427                 0.019778

# %%
data = df[['Adj Close', 'financial_scores']].values
target = df['Next Day'].values

# Normalize the input data
scalerX = MinMaxScaler(feature_range=(0, 1))
X_scaled = scalerX.fit_transform(data)

#Empty lists will be used for formatted training data
dataX = []
targetY = []

# How far to look in future
predict_days = 1
# number of past days
timestep = 7

for i in range(timestep, len(data) - predict_days +1):
    dataX.append(X_scaled[i - timestep:i, 0:data.shape[1]])
    targetY.append(target[i - 1:i + predict_days-1])

scalerY = MinMaxScaler(feature_range=(0, 1))
Y_scaled = scalerY.fit_transform(targetY)

# Split the dataset into training and testing sets
train_size = int(len(df) * 0.9)
trainX = dataX[:train_size]
testX = dataX[train_size:]

trainY = Y_scaled[:train_size]
testY = Y_scaled[train_size:]

trainX, trainY = np.array(trainX), np.array(trainY)
testX, testY = np.array(testX), np.array(testY)


# dates = df['Date']
# test_dates = dates[train_size:]

# %%
# Define the LSTM Model
model = Sequential()
model.add(LSTM(units=7, activation=LeakyReLU(alpha=0.3), input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
model.add(LSTM(units=4, activation=LeakyReLU(alpha=0.2), use_bias=True, return_sequences=True))
model.add(LSTM(units=2, activation=LeakyReLU(alpha=0.3), use_bias=True, return_sequences=False))
model.add(Dense(units=1))

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
checkpoint = ModelCheckpoint("model_test4.h5",
                             monitor='val_loss',
                             save_best_only=True,
                             mode='min',
                             verbose=1)

# %%
import tensorflow.keras.backend as K

def root_mean_squared_error(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
from tensorflow.keras.optimizers import Adam

# Compile the Model with a custom learning rate
learning_rate = 0.001
optimizer = Adam(learning_rate=learning_rate)
model.compile(optimizer=optimizer, loss=root_mean_squared_error)

# %%
# Train the Model
history1 = model.fit(trainX, trainY, epochs=320, batch_size=4, shuffle=False, verbose=1, validation_split=0.1, callbacks=[checkpoint])
# Out:
# Epoch 1/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0251
# Epoch 1: val_loss improved from inf to 0.23408, saving model to model_test4.h5
# 690/690 [==============================] - 26s 29ms/step - loss: 0.0251 - val_loss: 0.2341
# Epoch 2/320
#   1/690 [..............................] - ETA: 33s - loss: 0.4446
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 690/690 [==============================] - ETA: 0s - loss: 0.0572
# Epoch 2: val_loss improved from 0.23408 to 0.16229, saving model to model_test4.h5
# 690/690 [==============================] - 18s 26ms/step - loss: 0.0572 - val_loss: 0.1623
# Epoch 3/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0681
# Epoch 3: val_loss did not improve from 0.16229
# 690/690 [==============================] - 22s 32ms/step - loss: 0.0681 - val_loss: 0.1946
# Epoch 4/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0501
# Epoch 4: val_loss improved from 0.16229 to 0.15347, saving model to model_test4.h5
# 690/690 [==============================] - 16s 24ms/step - loss: 0.0501 - val_loss: 0.1535
# Epoch 5/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0293
# Epoch 5: val_loss improved from 0.15347 to 0.11811, saving model to model_test4.h5
# 690/690 [==============================] - 20s 29ms/step - loss: 0.0293 - val_loss: 0.1181
# Epoch 6/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0312
# Epoch 6: val_loss improved from 0.11811 to 0.09848, saving model to model_test4.h5
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0312 - val_loss: 0.0985
# Epoch 7/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0267
# Epoch 7: val_loss did not improve from 0.09848
# 690/690 [==============================] - 15s 22ms/step - loss: 0.0267 - val_loss: 0.1655
# Epoch 8/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0227
# Epoch 8: val_loss did not improve from 0.09848
# 690/690 [==============================] - 15s 22ms/step - loss: 0.0228 - val_loss: 0.1836
# Epoch 9/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0195
# Epoch 9: val_loss did not improve from 0.09848
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0195 - val_loss: 0.1323
# Epoch 10/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0185
# Epoch 10: val_loss did not improve from 0.09848
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0185 - val_loss: 0.1283
# Epoch 11/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0189
# Epoch 11: val_loss did not improve from 0.09848
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0189 - val_loss: 0.1576
# Epoch 12/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0186
# Epoch 12: val_loss did not improve from 0.09848
# 690/690 [==============================] - 16s 24ms/step - loss: 0.0186 - val_loss: 0.1670
# Epoch 13/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0171
# Epoch 13: val_loss did not improve from 0.09848
# 690/690 [==============================] - 16s 24ms/step - loss: 0.0171 - val_loss: 0.1576
# Epoch 14/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0168
# Epoch 14: val_loss did not improve from 0.09848
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0168 - val_loss: 0.1863
# Epoch 15/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0175
# Epoch 15: val_loss did not improve from 0.09848
# 690/690 [==============================] - 15s 22ms/step - loss: 0.0175 - val_loss: 0.1992
# Epoch 16/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0173
# Epoch 16: val_loss did not improve from 0.09848
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0173 - val_loss: 0.1757
# Epoch 17/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0171
# Epoch 17: val_loss did not improve from 0.09848
# 690/690 [==============================] - 15s 22ms/step - loss: 0.0171 - val_loss: 0.1907
# Epoch 18/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0172
# Epoch 18: val_loss did not improve from 0.09848
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0173 - val_loss: 0.1776
# Epoch 19/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0171
# Epoch 19: val_loss did not improve from 0.09848
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0171 - val_loss: 0.1990
# Epoch 20/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0164
# Epoch 20: val_loss did not improve from 0.09848
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0164 - val_loss: 0.1760
# Epoch 21/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0157
# Epoch 21: val_loss did not improve from 0.09848
# 690/690 [==============================] - 16s 24ms/step - loss: 0.0158 - val_loss: 0.2038
# Epoch 22/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0168
# Epoch 22: val_loss did not improve from 0.09848
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0169 - val_loss: 0.1882
# Epoch 23/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0154
# Epoch 23: val_loss did not improve from 0.09848
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0154 - val_loss: 0.1881
# Epoch 24/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0157
# Epoch 24: val_loss did not improve from 0.09848
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0157 - val_loss: 0.2048
# Epoch 25/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0149
# Epoch 25: val_loss did not improve from 0.09848
# 690/690 [==============================] - 15s 22ms/step - loss: 0.0149 - val_loss: 0.1884
# Epoch 26/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0140
# Epoch 26: val_loss did not improve from 0.09848
# 690/690 [==============================] - 15s 21ms/step - loss: 0.0140 - val_loss: 0.2067
# Epoch 27/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0137
# Epoch 27: val_loss did not improve from 0.09848
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0138 - val_loss: 0.1703
# Epoch 28/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0153
# Epoch 28: val_loss did not improve from 0.09848
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0153 - val_loss: 0.1586
# Epoch 29/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0138
# Epoch 29: val_loss did not improve from 0.09848
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0138 - val_loss: 0.1640
# Epoch 30/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0140
# Epoch 30: val_loss did not improve from 0.09848
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0140 - val_loss: 0.1561
# Epoch 31/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0134
# Epoch 31: val_loss did not improve from 0.09848
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0135 - val_loss: 0.1520
# Epoch 32/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0141
# Epoch 32: val_loss did not improve from 0.09848
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0141 - val_loss: 0.1315
# Epoch 33/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0130
# Epoch 33: val_loss did not improve from 0.09848
# 690/690 [==============================] - 15s 22ms/step - loss: 0.0130 - val_loss: 0.1606
# Epoch 34/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0133
# Epoch 34: val_loss did not improve from 0.09848
# 690/690 [==============================] - 15s 21ms/step - loss: 0.0133 - val_loss: 0.1336
# Epoch 35/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0132
# Epoch 35: val_loss did not improve from 0.09848
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0132 - val_loss: 0.1261
# Epoch 36/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0135
# Epoch 36: val_loss did not improve from 0.09848
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0135 - val_loss: 0.1057
# Epoch 37/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0122
# Epoch 37: val_loss improved from 0.09848 to 0.06628, saving model to model_test4.h5
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0122 - val_loss: 0.0663
# Epoch 38/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0129
# Epoch 38: val_loss improved from 0.06628 to 0.04310, saving model to model_test4.h5
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0129 - val_loss: 0.0431
# Epoch 39/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0114
# Epoch 39: val_loss did not improve from 0.04310
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0114 - val_loss: 0.0504
# Epoch 40/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0124
# Epoch 40: val_loss did not improve from 0.04310
# 690/690 [==============================] - 15s 22ms/step - loss: 0.0124 - val_loss: 0.0522
# Epoch 41/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0116
# Epoch 41: val_loss did not improve from 0.04310
# 690/690 [==============================] - 15s 22ms/step - loss: 0.0116 - val_loss: 0.0491
# Epoch 42/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0113
# Epoch 42: val_loss improved from 0.04310 to 0.02325, saving model to model_test4.h5
# 690/690 [==============================] - 15s 22ms/step - loss: 0.0113 - val_loss: 0.0233
# Epoch 43/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0109
# Epoch 43: val_loss improved from 0.02325 to 0.02057, saving model to model_test4.h5
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0109 - val_loss: 0.0206
# Epoch 44/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0107
# Epoch 44: val_loss improved from 0.02057 to 0.01732, saving model to model_test4.h5
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0107 - val_loss: 0.0173
# Epoch 45/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0102
# Epoch 45: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 24ms/step - loss: 0.0102 - val_loss: 0.0332
# Epoch 46/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0109
# Epoch 46: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0110 - val_loss: 0.0296
# Epoch 47/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0115
# Epoch 47: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0116 - val_loss: 0.0353
# Epoch 48/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0137
# Epoch 48: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0137 - val_loss: 0.0414
# Epoch 49/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0115
# Epoch 49: val_loss did not improve from 0.01732
# 690/690 [==============================] - 15s 21ms/step - loss: 0.0115 - val_loss: 0.0481
# Epoch 50/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0113
# Epoch 50: val_loss did not improve from 0.01732
# 690/690 [==============================] - 15s 21ms/step - loss: 0.0113 - val_loss: 0.0413
# Epoch 51/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0117
# Epoch 51: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0117 - val_loss: 0.0280
# Epoch 52/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 52: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0108 - val_loss: 0.0394
# Epoch 53/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0099
# Epoch 53: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0100 - val_loss: 0.0436
# Epoch 54/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0095
# Epoch 54: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0095 - val_loss: 0.0444
# Epoch 55/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0094
# Epoch 55: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0094 - val_loss: 0.0359
# Epoch 56/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0098
# Epoch 56: val_loss did not improve from 0.01732
# 690/690 [==============================] - 15s 21ms/step - loss: 0.0098 - val_loss: 0.0267
# Epoch 57/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0093
# Epoch 57: val_loss did not improve from 0.01732
# 690/690 [==============================] - 14s 21ms/step - loss: 0.0093 - val_loss: 0.0258
# Epoch 58/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0088
# Epoch 58: val_loss did not improve from 0.01732
# 690/690 [==============================] - 15s 22ms/step - loss: 0.0088 - val_loss: 0.0288
# Epoch 59/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0094
# Epoch 59: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0094 - val_loss: 0.0288
# Epoch 60/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0092
# Epoch 60: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0092 - val_loss: 0.0232
# Epoch 61/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0085
# Epoch 61: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0085 - val_loss: 0.0277
# Epoch 62/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0092
# Epoch 62: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0092 - val_loss: 0.0254
# Epoch 63/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0091
# Epoch 63: val_loss did not improve from 0.01732
# 690/690 [==============================] - 15s 22ms/step - loss: 0.0091 - val_loss: 0.0223
# Epoch 64/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0085
# Epoch 64: val_loss did not improve from 0.01732
# 690/690 [==============================] - 15s 22ms/step - loss: 0.0085 - val_loss: 0.0241
# Epoch 65/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0088
# Epoch 65: val_loss did not improve from 0.01732
# 690/690 [==============================] - 15s 22ms/step - loss: 0.0088 - val_loss: 0.0241
# Epoch 66/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0082
# Epoch 66: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0082 - val_loss: 0.0259
# Epoch 67/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0089
# Epoch 67: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 24ms/step - loss: 0.0089 - val_loss: 0.0222
# Epoch 68/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0081
# Epoch 68: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0081 - val_loss: 0.0263
# Epoch 69/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0089
# Epoch 69: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0089 - val_loss: 0.0221
# Epoch 70/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0079
# Epoch 70: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0079 - val_loss: 0.0253
# Epoch 71/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0082
# Epoch 71: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0082 - val_loss: 0.0307
# Epoch 72/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0086
# Epoch 72: val_loss did not improve from 0.01732
# 690/690 [==============================] - 15s 22ms/step - loss: 0.0086 - val_loss: 0.0296
# Epoch 73/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0079
# Epoch 73: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0079 - val_loss: 0.0343
# Epoch 74/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0082
# Epoch 74: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0082 - val_loss: 0.0305
# Epoch 75/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 75: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 24ms/step - loss: 0.0078 - val_loss: 0.0361
# Epoch 76/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0087
# Epoch 76: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 24ms/step - loss: 0.0087 - val_loss: 0.0318
# Epoch 77/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0076
# Epoch 77: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 24ms/step - loss: 0.0076 - val_loss: 0.0462
# Epoch 78/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0084
# Epoch 78: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 24ms/step - loss: 0.0084 - val_loss: 0.0251
# Epoch 79/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0072
# Epoch 79: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0072 - val_loss: 0.0359
# Epoch 80/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 80: val_loss did not improve from 0.01732
# 690/690 [==============================] - 18s 27ms/step - loss: 0.0078 - val_loss: 0.0480
# Epoch 81/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0083
# Epoch 81: val_loss did not improve from 0.01732
# 690/690 [==============================] - 18s 26ms/step - loss: 0.0083 - val_loss: 0.0252
# Epoch 82/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0072
# Epoch 82: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0072 - val_loss: 0.0272
# Epoch 83/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0074
# Epoch 83: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0074 - val_loss: 0.0283
# Epoch 84/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0074
# Epoch 84: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0074 - val_loss: 0.0278
# Epoch 85/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0075
# Epoch 85: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0075 - val_loss: 0.0295
# Epoch 86/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0075
# Epoch 86: val_loss did not improve from 0.01732
# 690/690 [==============================] - 18s 25ms/step - loss: 0.0075 - val_loss: 0.0317
# Epoch 87/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0072
# Epoch 87: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0072 - val_loss: 0.0385
# Epoch 88/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0078
# Epoch 88: val_loss did not improve from 0.01732
# 690/690 [==============================] - 18s 26ms/step - loss: 0.0078 - val_loss: 0.0311
# Epoch 89/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0070
# Epoch 89: val_loss did not improve from 0.01732
# 690/690 [==============================] - 18s 26ms/step - loss: 0.0070 - val_loss: 0.0332
# Epoch 90/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0074
# Epoch 90: val_loss did not improve from 0.01732
# 690/690 [==============================] - 18s 26ms/step - loss: 0.0074 - val_loss: 0.0378
# Epoch 91/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0069
# Epoch 91: val_loss did not improve from 0.01732
# 690/690 [==============================] - 18s 26ms/step - loss: 0.0069 - val_loss: 0.0355
# Epoch 92/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0072
# Epoch 92: val_loss did not improve from 0.01732
# 690/690 [==============================] - 18s 26ms/step - loss: 0.0073 - val_loss: 0.0340
# Epoch 93/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 93: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0071 - val_loss: 0.0363
# Epoch 94/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0072
# Epoch 94: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0072 - val_loss: 0.0345
# Epoch 95/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0070
# Epoch 95: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0070 - val_loss: 0.0464
# Epoch 96/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0073
# Epoch 96: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0073 - val_loss: 0.0302
# Epoch 97/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0067
# Epoch 97: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0067 - val_loss: 0.0371
# Epoch 98/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0074
# Epoch 98: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0074 - val_loss: 0.0636
# Epoch 99/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0074
# Epoch 99: val_loss did not improve from 0.01732
# 690/690 [==============================] - 18s 26ms/step - loss: 0.0074 - val_loss: 0.0382
# Epoch 100/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0069
# Epoch 100: val_loss did not improve from 0.01732
# 690/690 [==============================] - 18s 26ms/step - loss: 0.0069 - val_loss: 0.0564
# Epoch 101/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0075
# Epoch 101: val_loss did not improve from 0.01732
# 690/690 [==============================] - 18s 26ms/step - loss: 0.0075 - val_loss: 0.0295
# Epoch 102/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0066
# Epoch 102: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0066 - val_loss: 0.0369
# Epoch 103/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0067
# Epoch 103: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0067 - val_loss: 0.0397
# Epoch 104/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 104: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 24ms/step - loss: 0.0071 - val_loss: 0.0413
# Epoch 105/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0069
# Epoch 105: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0069 - val_loss: 0.0567
# Epoch 106/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0072
# Epoch 106: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0073 - val_loss: 0.0297
# Epoch 107/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0064
# Epoch 107: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0064 - val_loss: 0.0379
# Epoch 108/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0067
# Epoch 108: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0067 - val_loss: 0.0556
# Epoch 109/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0069
# Epoch 109: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0069 - val_loss: 0.0311
# Epoch 110/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0065
# Epoch 110: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0066 - val_loss: 0.0353
# Epoch 111/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0067
# Epoch 111: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 24ms/step - loss: 0.0068 - val_loss: 0.0332
# Epoch 112/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0064
# Epoch 112: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0064 - val_loss: 0.0434
# Epoch 113/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0066
# Epoch 113: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0066 - val_loss: 0.0666
# Epoch 114/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0072
# Epoch 114: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0072 - val_loss: 0.0387
# Epoch 115/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0068
# Epoch 115: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0068 - val_loss: 0.0402
# Epoch 116/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0068
# Epoch 116: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0068 - val_loss: 0.0488
# Epoch 117/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0066
# Epoch 117: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0066 - val_loss: 0.0346
# Epoch 118/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0065
# Epoch 118: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 24ms/step - loss: 0.0066 - val_loss: 0.0559
# Epoch 119/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0066
# Epoch 119: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0067 - val_loss: 0.0355
# Epoch 120/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0066
# Epoch 120: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0066 - val_loss: 0.0385
# Epoch 121/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0064
# Epoch 121: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0064 - val_loss: 0.0351
# Epoch 122/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0064
# Epoch 122: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 24ms/step - loss: 0.0064 - val_loss: 0.0513
# Epoch 123/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0066
# Epoch 123: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0066 - val_loss: 0.0350
# Epoch 124/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0063
# Epoch 124: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0063 - val_loss: 0.0519
# Epoch 125/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0068
# Epoch 125: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0068 - val_loss: 0.0536
# Epoch 126/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0066
# Epoch 126: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0066 - val_loss: 0.0548
# Epoch 127/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0066
# Epoch 127: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 24ms/step - loss: 0.0066 - val_loss: 0.0562
# Epoch 128/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0065
# Epoch 128: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0066 - val_loss: 0.0558
# Epoch 129/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0065
# Epoch 129: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0065 - val_loss: 0.0543
# Epoch 130/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0065
# Epoch 130: val_loss did not improve from 0.01732
# 690/690 [==============================] - 18s 25ms/step - loss: 0.0065 - val_loss: 0.0543
# Epoch 131/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0065
# Epoch 131: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0065 - val_loss: 0.0532
# Epoch 132/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0065
# Epoch 132: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 24ms/step - loss: 0.0065 - val_loss: 0.0547
# Epoch 133/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0064
# Epoch 133: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0065 - val_loss: 0.0511
# Epoch 134/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0064
# Epoch 134: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 24ms/step - loss: 0.0064 - val_loss: 0.0522
# Epoch 135/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0064
# Epoch 135: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0064 - val_loss: 0.0511
# Epoch 136/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0063
# Epoch 136: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0063 - val_loss: 0.0523
# Epoch 137/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0063
# Epoch 137: val_loss did not improve from 0.01732
# 690/690 [==============================] - 18s 25ms/step - loss: 0.0063 - val_loss: 0.0508
# Epoch 138/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0063
# Epoch 138: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0063 - val_loss: 0.0513
# Epoch 139/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0062
# Epoch 139: val_loss did not improve from 0.01732
# 690/690 [==============================] - 19s 27ms/step - loss: 0.0062 - val_loss: 0.0513
# Epoch 140/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0062
# Epoch 140: val_loss did not improve from 0.01732
# 690/690 [==============================] - 19s 27ms/step - loss: 0.0062 - val_loss: 0.0503
# Epoch 141/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0062
# Epoch 141: val_loss did not improve from 0.01732
# 690/690 [==============================] - 19s 27ms/step - loss: 0.0062 - val_loss: 0.0509
# Epoch 142/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0061
# Epoch 142: val_loss did not improve from 0.01732
# 690/690 [==============================] - 18s 26ms/step - loss: 0.0061 - val_loss: 0.0495
# Epoch 143/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0061
# Epoch 143: val_loss did not improve from 0.01732
# 690/690 [==============================] - 18s 26ms/step - loss: 0.0061 - val_loss: 0.0497
# Epoch 144/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0061
# Epoch 144: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0061 - val_loss: 0.0506
# Epoch 145/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0061
# Epoch 145: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0061 - val_loss: 0.0495
# Epoch 146/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0061
# Epoch 146: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0061 - val_loss: 0.0494
# Epoch 147/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0061
# Epoch 147: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0061 - val_loss: 0.0488
# Epoch 148/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0060
# Epoch 148: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0060 - val_loss: 0.0491
# Epoch 149/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0060
# Epoch 149: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0060 - val_loss: 0.0481
# Epoch 150/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0060
# Epoch 150: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0060 - val_loss: 0.0483
# Epoch 151/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0059
# Epoch 151: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0059 - val_loss: 0.0482
# Epoch 152/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0059
# Epoch 152: val_loss did not improve from 0.01732
# 690/690 [==============================] - 18s 25ms/step - loss: 0.0059 - val_loss: 0.0473
# Epoch 153/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0059
# Epoch 153: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0059 - val_loss: 0.0474
# Epoch 154/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0059
# Epoch 154: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0059 - val_loss: 0.0483
# Epoch 155/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0058
# Epoch 155: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0059 - val_loss: 0.0451
# Epoch 156/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0059
# Epoch 156: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0059 - val_loss: 0.0457
# Epoch 157/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0058
# Epoch 157: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0059 - val_loss: 0.0464
# Epoch 158/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0059
# Epoch 158: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0059 - val_loss: 0.0448
# Epoch 159/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0059
# Epoch 159: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0059 - val_loss: 0.0449
# Epoch 160/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0058
# Epoch 160: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0058 - val_loss: 0.0441
# Epoch 161/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0058
# Epoch 161: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0058 - val_loss: 0.0449
# Epoch 162/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0058
# Epoch 162: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0058 - val_loss: 0.0445
# Epoch 163/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0058
# Epoch 163: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0058 - val_loss: 0.0433
# Epoch 164/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0058
# Epoch 164: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0058 - val_loss: 0.0453
# Epoch 165/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0057
# Epoch 165: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0057 - val_loss: 0.0433
# Epoch 166/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0057
# Epoch 166: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0057 - val_loss: 0.0352
# Epoch 167/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0057
# Epoch 167: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0057 - val_loss: 0.0394
# Epoch 168/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0057
# Epoch 168: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0057 - val_loss: 0.0407
# Epoch 169/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0056
# Epoch 169: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0056 - val_loss: 0.0378
# Epoch 170/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0057
# Epoch 170: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0057 - val_loss: 0.0406
# Epoch 171/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0055
# Epoch 171: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0056 - val_loss: 0.0314
# Epoch 172/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0057
# Epoch 172: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0057 - val_loss: 0.0400
# Epoch 173/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0056
# Epoch 173: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0056 - val_loss: 0.0332
# Epoch 174/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0056
# Epoch 174: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0056 - val_loss: 0.0330
# Epoch 175/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0055
# Epoch 175: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 24ms/step - loss: 0.0055 - val_loss: 0.0329
# Epoch 176/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0052
# Epoch 176: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0052 - val_loss: 0.0351
# Epoch 177/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0055
# Epoch 177: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0055 - val_loss: 0.0366
# Epoch 178/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0055
# Epoch 178: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 24ms/step - loss: 0.0055 - val_loss: 0.0346
# Epoch 179/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0055
# Epoch 179: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0055 - val_loss: 0.0377
# Epoch 180/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0056
# Epoch 180: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0056 - val_loss: 0.0397
# Epoch 181/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0056
# Epoch 181: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0056 - val_loss: 0.0391
# Epoch 182/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0056
# Epoch 182: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0056 - val_loss: 0.0386
# Epoch 183/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0056
# Epoch 183: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0056 - val_loss: 0.0419
# Epoch 184/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0057
# Epoch 184: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0057 - val_loss: 0.0423
# Epoch 185/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0059
# Epoch 185: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0059 - val_loss: 0.0597
# Epoch 186/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0060
# Epoch 186: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0060 - val_loss: 0.0649
# Epoch 187/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0054
# Epoch 187: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0054 - val_loss: 0.0405
# Epoch 188/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0056
# Epoch 188: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0056 - val_loss: 0.0367
# Epoch 189/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0054
# Epoch 189: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0054 - val_loss: 0.0384
# Epoch 190/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0054
# Epoch 190: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0054 - val_loss: 0.0389
# Epoch 191/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0055
# Epoch 191: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0055 - val_loss: 0.0372
# Epoch 192/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0056
# Epoch 192: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0056 - val_loss: 0.0355
# Epoch 193/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0056
# Epoch 193: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 24ms/step - loss: 0.0056 - val_loss: 0.0397
# Epoch 194/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0054
# Epoch 194: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 24ms/step - loss: 0.0054 - val_loss: 0.0383
# Epoch 195/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0055
# Epoch 195: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0055 - val_loss: 0.0388
# Epoch 196/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0054
# Epoch 196: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0054 - val_loss: 0.0390
# Epoch 197/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0053
# Epoch 197: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0054 - val_loss: 0.0389
# Epoch 198/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0055
# Epoch 198: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0055 - val_loss: 0.0372
# Epoch 199/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0055
# Epoch 199: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0055 - val_loss: 0.0310
# Epoch 200/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0056
# Epoch 200: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0056 - val_loss: 0.0385
# Epoch 201/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0055
# Epoch 201: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0055 - val_loss: 0.0361
# Epoch 202/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0054
# Epoch 202: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0055 - val_loss: 0.0343
# Epoch 203/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0054
# Epoch 203: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0054 - val_loss: 0.0290
# Epoch 204/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0054
# Epoch 204: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0054 - val_loss: 0.0261
# Epoch 205/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0053
# Epoch 205: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0053 - val_loss: 0.0423
# Epoch 206/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0054
# Epoch 206: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0054 - val_loss: 0.0439
# Epoch 207/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0054
# Epoch 207: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0055 - val_loss: 0.0359
# Epoch 208/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0054
# Epoch 208: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0054 - val_loss: 0.0442
# Epoch 209/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0057
# Epoch 209: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0057 - val_loss: 0.0493
# Epoch 210/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0056
# Epoch 210: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0057 - val_loss: 0.0544
# Epoch 211/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0055
# Epoch 211: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0055 - val_loss: 0.0504
# Epoch 212/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0056
# Epoch 212: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0056 - val_loss: 0.0488
# Epoch 213/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0056
# Epoch 213: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0056 - val_loss: 0.0486
# Epoch 214/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0055
# Epoch 214: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0055 - val_loss: 0.0410
# Epoch 215/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0058
# Epoch 215: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0058 - val_loss: 0.0423
# Epoch 216/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0054
# Epoch 216: val_loss did not improve from 0.01732
# ...
# Epoch 248: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0056 - val_loss: 0.0558
# Epoch 249/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0056
# Epoch 249: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0056 - val_loss: 0.0519
# Epoch 250/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0055
# Epoch 250: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 24ms/step - loss: 0.0055 - val_loss: 0.0473
# Epoch 251/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0055
# Epoch 251: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0055 - val_loss: 0.0468
# Epoch 252/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0055
# Epoch 252: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0055 - val_loss: 0.0448
# Epoch 253/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0055
# Epoch 253: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0055 - val_loss: 0.0420
# Epoch 254/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0054
# Epoch 254: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0054 - val_loss: 0.0400
# Epoch 255/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0054
# Epoch 255: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0055 - val_loss: 0.0389
# Epoch 256/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0054
# Epoch 256: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0054 - val_loss: 0.0370
# Epoch 257/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0054
# Epoch 257: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0054 - val_loss: 0.0346
# Epoch 258/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0054
# Epoch 258: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 24ms/step - loss: 0.0054 - val_loss: 0.0329
# Epoch 259/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0055
# Epoch 259: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0055 - val_loss: 0.0318
# Epoch 260/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0054
# Epoch 260: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0054 - val_loss: 0.0317
# Epoch 261/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0054
# Epoch 261: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0054 - val_loss: 0.0314
# Epoch 262/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0054
# Epoch 262: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0054 - val_loss: 0.0287
# Epoch 263/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0054
# Epoch 263: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0054 - val_loss: 0.0275
# Epoch 264/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0054
# Epoch 264: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 24ms/step - loss: 0.0054 - val_loss: 0.0296
# Epoch 265/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0052
# Epoch 265: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 23ms/step - loss: 0.0052 - val_loss: 0.0330
# Epoch 266/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0053
# Epoch 266: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0053 - val_loss: 0.0414
# Epoch 267/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0053
# Epoch 267: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0053 - val_loss: 0.0442
# Epoch 268/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0054
# Epoch 268: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0054 - val_loss: 0.0423
# Epoch 269/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0053
# Epoch 269: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0054 - val_loss: 0.0444
# Epoch 270/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0054
# Epoch 270: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0054 - val_loss: 0.0472
# Epoch 271/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0055
# Epoch 271: val_loss did not improve from 0.01732
# 690/690 [==============================] - 18s 26ms/step - loss: 0.0055 - val_loss: 0.0468
# Epoch 272/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0055
# Epoch 272: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0055 - val_loss: 0.0359
# Epoch 273/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0055
# Epoch 273: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 24ms/step - loss: 0.0055 - val_loss: 0.0344
# Epoch 274/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0054
# Epoch 274: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0054 - val_loss: 0.0457
# Epoch 275/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0057
# Epoch 275: val_loss did not improve from 0.01732
# 690/690 [==============================] - 18s 25ms/step - loss: 0.0057 - val_loss: 0.0942
# Epoch 276/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0058
# Epoch 276: val_loss did not improve from 0.01732
# 690/690 [==============================] - 18s 25ms/step - loss: 0.0058 - val_loss: 0.0887
# Epoch 277/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0056
# Epoch 277: val_loss did not improve from 0.01732
# 690/690 [==============================] - 18s 25ms/step - loss: 0.0057 - val_loss: 0.0848
# Epoch 278/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0056
# Epoch 278: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0056 - val_loss: 0.0808
# Epoch 279/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0055
# Epoch 279: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0056 - val_loss: 0.0816
# Epoch 280/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0055
# Epoch 280: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 24ms/step - loss: 0.0055 - val_loss: 0.0770
# Epoch 281/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0054
# Epoch 281: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 24ms/step - loss: 0.0055 - val_loss: 0.0758
# Epoch 282/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0052
# Epoch 282: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0052 - val_loss: 0.0482
# Epoch 283/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0051
# Epoch 283: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0051 - val_loss: 0.0391
# Epoch 284/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0053
# Epoch 284: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0053 - val_loss: 0.0431
# Epoch 285/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0054
# Epoch 285: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0054 - val_loss: 0.0525
# Epoch 286/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0055
# Epoch 286: val_loss did not improve from 0.01732
# 690/690 [==============================] - 18s 25ms/step - loss: 0.0055 - val_loss: 0.0484
# Epoch 287/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0053
# Epoch 287: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0053 - val_loss: 0.0848
# Epoch 288/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0054
# Epoch 288: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 24ms/step - loss: 0.0054 - val_loss: 0.0549
# Epoch 289/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0051
# Epoch 289: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0051 - val_loss: 0.0563
# Epoch 290/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0053
# Epoch 290: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0053 - val_loss: 0.0521
# Epoch 291/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0052
# Epoch 291: val_loss did not improve from 0.01732
# 690/690 [==============================] - 18s 26ms/step - loss: 0.0052 - val_loss: 0.0391
# Epoch 292/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0053
# Epoch 292: val_loss did not improve from 0.01732
# 690/690 [==============================] - 18s 25ms/step - loss: 0.0053 - val_loss: 0.0579
# Epoch 293/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0053
# Epoch 293: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0053 - val_loss: 0.0719
# Epoch 294/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0053
# Epoch 294: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0053 - val_loss: 0.0559
# Epoch 295/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0051
# Epoch 295: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 24ms/step - loss: 0.0051 - val_loss: 0.0508
# Epoch 296/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0053
# Epoch 296: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 24ms/step - loss: 0.0053 - val_loss: 0.0405
# Epoch 297/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0052
# Epoch 297: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 24ms/step - loss: 0.0052 - val_loss: 0.0398
# Epoch 298/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0052
# Epoch 298: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0052 - val_loss: 0.0356
# Epoch 299/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0056
# Epoch 299: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0056 - val_loss: 0.0813
# Epoch 300/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0054
# Epoch 300: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0054 - val_loss: 0.0750
# Epoch 301/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0056
# Epoch 301: val_loss did not improve from 0.01732
# 690/690 [==============================] - 18s 26ms/step - loss: 0.0056 - val_loss: 0.0752
# Epoch 302/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0052
# Epoch 302: val_loss did not improve from 0.01732
# 690/690 [==============================] - 18s 25ms/step - loss: 0.0052 - val_loss: 0.0734
# Epoch 303/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0055
# Epoch 303: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 24ms/step - loss: 0.0055 - val_loss: 0.0714
# Epoch 304/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0053
# Epoch 304: val_loss did not improve from 0.01732
# 690/690 [==============================] - 16s 24ms/step - loss: 0.0053 - val_loss: 0.0705
# Epoch 305/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0054
# Epoch 305: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0054 - val_loss: 0.0705
# Epoch 306/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0054
# Epoch 306: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0054 - val_loss: 0.0642
# Epoch 307/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0053
# Epoch 307: val_loss did not improve from 0.01732
# 690/690 [==============================] - 18s 26ms/step - loss: 0.0053 - val_loss: 0.0703
# Epoch 308/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0053
# Epoch 308: val_loss did not improve from 0.01732
# 690/690 [==============================] - 18s 26ms/step - loss: 0.0053 - val_loss: 0.0691
# Epoch 309/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0053
# Epoch 309: val_loss did not improve from 0.01732
# 690/690 [==============================] - 18s 26ms/step - loss: 0.0053 - val_loss: 0.0659
# Epoch 310/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0052
# Epoch 310: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0052 - val_loss: 0.0601
# Epoch 311/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0049
# Epoch 311: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0050 - val_loss: 0.0470
# Epoch 312/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0053
# Epoch 312: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0053 - val_loss: 0.0593
# Epoch 313/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0054
# Epoch 313: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0054 - val_loss: 0.0777
# Epoch 314/320
# 688/690 [============================>.] - ETA: 0s - loss: 0.0053
# Epoch 314: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0053 - val_loss: 0.0739
# Epoch 315/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0053
# Epoch 315: val_loss did not improve from 0.01732
# 690/690 [==============================] - 18s 25ms/step - loss: 0.0053 - val_loss: 0.0684
# Epoch 316/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0052
# Epoch 316: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0052 - val_loss: 0.0623
# Epoch 317/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 317: val_loss did not improve from 0.01732
# 690/690 [==============================] - 18s 25ms/step - loss: 0.0049 - val_loss: 0.0472
# Epoch 318/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0053
# Epoch 318: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0053 - val_loss: 0.0613
# Epoch 319/320
# 690/690 [==============================] - ETA: 0s - loss: 0.0055
# Epoch 319: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 25ms/step - loss: 0.0055 - val_loss: 0.0744
# Epoch 320/320
# 689/690 [============================>.] - ETA: 0s - loss: 0.0052
# Epoch 320: val_loss did not improve from 0.01732
# 690/690 [==============================] - 17s 24ms/step - loss: 0.0052 - val_loss: 0.0705

# %%
model.save('model_test320_4_1.h5')

# %%
# Access the training history
# training_loss += history3.history['loss']
training_loss = history1.history['loss'] + history2.history['loss'] + history3.history['loss']
# validation_loss += history3.history['val_loss']
validation_loss = history1.history['val_loss'] + history2.history['val_loss'] + history3.history['val_loss']

# Create an array of epoch numbers for the x-axis
epochs = range(1, len(training_loss) + 1)

# Plot training and validation loss
plt.figure(figsize=(16, 8))
plt.plot(epochs, training_loss, 'b', label='Training Loss')
plt.plot(epochs, validation_loss, 'r', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
predictions_scaled = model.predict(testX)
predictions = scalerY.inverse_transform(predictions_scaled)

# %%
y_inverse = scalerY.inverse_transform(testY)

# %%
# Plot training and validation loss
plt.figure(figsize=(10, 6))
plt.xticks(range(0, len(y_inverse), 16))
plt.plot(predictions, 'r', label='Predicted Prices')
plt.plot(y_inverse, 'b', label='Actual Prices')
plt.title('Predicted and Actual Prices')
plt.xlabel('Dates')
plt.ylabel('Prices')
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Calculate Mean Absolute Error
mae = mean_absolute_error(y_inverse, predictions)
print(f"Mean Absolute Error: {mae}")

# Calculate Mean Squared Error
mse = mean_squared_error(y_inverse, predictions)
print(f"Mean Squared Error: {mse}")

# Calculate Root Mean Squared Error
rmse = np.sqrt(mse)
print(f"Root Mean Squared Error: {rmse}")

# Calculate Mean Absolute Percentage Error
mape = np.mean(np.abs((y_inverse - predictions) / y_inverse)) * 100
print(f"Mean Absolute Percentage Error: {mape} %")

# %%
# Calculate Mean Absolute Error
mae = mean_absolute_error(testY, predictions_scaled)
print(f"Mean Absolute Error: {mae}")

# Calculate Mean Squared Error
mse = mean_squared_error(testY, predictions_scaled)
print(f"Mean Squared Error: {mse}")

# Calculate Root Mean Squared Error
rmse = np.sqrt(mse)
print(f"Root Mean Squared Error: {rmse}")

# Calculate Mean Absolute Percentage Error
mape = np.mean(np.abs((testY - predictions_scaled) / testY)) * 100
print(f"Mean Absolute Percentage Error: {mape} %")

# %% [markdown]
# ##Testing the Model

# %%
# !pip install tensorflow --quiet

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras import regularizers
from tensorflow.keras.layers import LeakyReLU
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/Dataset/Stock Price Prediction/Prices/final_v2.csv')
df.drop('Unnamed: 0.1', axis = 1, inplace=True)
df.drop('Unnamed: 0', axis = 1, inplace=True)

# %%
data = df[['Adj Close', 'Volume']].values
target = df['Next Day'].values

# Normalize the input data
scalerX = MinMaxScaler(feature_range=(0, 1))
X_scaled = scalerX.fit_transform(data)

#Empty lists will be used for formatted training data
dataX = []
targetY = []

# How far to look in future
predict_days = 1
# number of past days
timestep = 14

for i in range(timestep, len(data) - predict_days +1):
    dataX.append(X_scaled[i - timestep:i, 0:data.shape[1]])
    targetY.append(target[i - 1:i + predict_days-1])

scalerY = MinMaxScaler(feature_range=(0, 1))
Y_scaled = scalerY.fit_transform(targetY)

# Split the dataset into training and testing sets
train_size = int(len(df) * 0.9)
trainX = dataX[:train_size]
testX = dataX[train_size:]

trainY = Y_scaled[:train_size]
testY = Y_scaled[train_size:]

trainX, trainY = np.array(trainX), np.array(trainY)
testX, testY = np.array(testX), np.array(testY)

# dates = df['Date']
# test_dates = dates[train_size:]

# %%
import tensorflow.keras.backend as K

def root_mean_squared_error(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
import time
time.sleep(8)
import tensorflow as tf
model = tf.keras.models.load_model('model_test4.h5')
# , custom_objects={'root_mean_squared_error': root_mean_squared_error}

# %%
predictions_scaled1 = model.predict(testX)
predictions1 = scalerY.inverse_transform(predictions_scaled1)

# %%
y_inverse = scalerY.inverse_transform(testY)

# %%
# Plot training and validation loss
plt.figure(figsize=(10, 6))
plt.xticks(range(0, len(y_inverse), 16))
plt.plot(predictions1, 'r', label='Predicted Prices')
plt.plot(y_inverse, 'b', label='Actual Prices')
plt.title('Predicted and Actual Prices')
plt.xlabel('Dates')
plt.ylabel('Prices')
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# %%
# Calculate Mean Absolute Error
mae = mean_absolute_error(y_inverse, predictions1)
print(f"Mean Absolute Error: {mae}")

# Calculate Mean Squared Error
mse = mean_squared_error(y_inverse, predictions1)
print(f"Mean Squared Error: {mse}")

# Calculate Root Mean Squared Error
rmse = np.sqrt(mse)
print(f"Root Mean Squared Error: {rmse}")

# Calculate Mean Absolute Percentage Error
mape = np.mean(np.abs((y_inverse - predictions1) / y_inverse)) * 100
print(f"Mean Absolute Percentage Error: {mape} %")

# %%
# Calculate Mean Absolute Error
mae = mean_absolute_error(testY, predictions_scaled1)
print(f"Mean Absolute Error: {mae}")

# Calculate Mean Squared Error
mse = mean_squared_error(testY, predictions_scaled1)
print(f"Mean Squared Error: {mse}")

# Calculate Root Mean Squared Error
rmse = np.sqrt(mse)
print(f"Root Mean Squared Error: {rmse}")

# Calculate Mean Absolute Percentage Error
mape = np.mean(np.abs((testY - predictions_scaled1) / testY)) * 100
print(f"Mean Absolute Percentage Error: {mape} %")
